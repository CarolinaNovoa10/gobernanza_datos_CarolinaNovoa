# %% [markdown]
# <a href="https://colab.research.google.com/github/CarolinaNovoa10/gobernanza_datos_CarolinaNovoa/blob/main/Infograf%C3%ADa.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Infografía
# ## **Comparación de Normativas de Gobernanza de Datos entre Colombia e Italia**
#
# ![Infografía - Colombia e Italia.jpg](data:image/jpeg;base64,...)
